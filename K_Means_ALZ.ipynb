# %%
import os
import sys
import pandas as pd
from pathlib import Path
import numpy as np
from kmodes.kmodes import KModes
from kmodes.kprototypes import KPrototypes

# %%
DATA_DIR = "data"
data_files = [str(filePath) for filePath in Path(DATA_DIR).glob("**/*") if filePath.is_file()]
data_labels = ['Debtor', 'Invoice', 'Payments']
data_dict = {data_labels[i]: pd.read_csv(data_files[i]) for i in range(len(data_labels))}

# %%
df = pd.merge(data_dict['Invoice'], data_dict['Payments'], on = ['InvoiceKey', 'CustomerKey'])

# %%
df
# Out:
#         InvoiceKey  CustomerKey  IsCreditInvoice  RaisedDate     DueDate  \
# 0        197057173     16776992                1  2018-01-02  2018-01-02
# 1        196559812     16837363                1  2018-01-02  2018-01-02
# 2        195300967     16724474                1  2018-01-03  2018-01-03
# 3        195519971     16745090                0  2018-01-03  2018-03-02
# 4        196697217     16817529                1  2018-01-03  2018-01-03
# ...            ...          ...              ...         ...         ...
# 361514   196340182     16725749                0  2019-06-30  2019-07-30
# 361515   196340751     16728765                0  2019-06-30  2019-07-30
# 361516   196341240     16971160                0  2019-06-30  2019-07-30
# 361517   196341411     16764236                0  2019-06-30  2019-07-30
# 361518   196341507     16832368                0  2019-06-30  2019-07-30
#
#         OriginalInvoiceAmount  AmountOutstanding StatementTransactionType  \
# 0                     -645.66                0.0                      JRN
# 1                     -139.37                0.0                      JRN
# 2                      -88.50                0.0                      JRN
# 3                      168.00                0.0                      INV
# 4                     -626.38                0.0                      JRN
# ...                       ...                ...                      ...
# 361514                  95.90                0.0                      INV
# 361515                 406.09                0.0                      INV
# 361516                 130.56                0.0                      INV
# 361517                  15.00                0.0                      INV
# 361518                  74.76                0.0                      INV
#
#                     ExtractDate  PaymentValue PaymentDate     PaymentType
# 0       2020-09-18 16:21:06.333       -645.66  2018-12-17  Barclays Multi
# 1       2020-09-18 16:21:06.333       -139.37  2018-11-01  Barclays Multi
# 2       2020-09-18 16:21:06.333        -88.50  2018-09-24  Barclays Multi
# 3       2020-09-18 16:21:06.333        168.00  2018-11-23  Barclays Multi
# 4       2020-09-18 16:21:06.333       -626.38  2019-12-17  Barclays Multi
# ...                         ...           ...         ...             ...
# 361514  2020-09-18 16:21:06.333         95.90  2019-08-14  Barclays Multi
# 361515  2020-09-18 16:21:06.333        406.09  2019-08-05  Barclays Multi
# 361516  2020-09-18 16:21:06.333        130.56  2019-07-24         CheckM8
# 361517  2020-09-18 16:21:06.333         15.00  2019-07-08  Barclays Multi
# 361518  2020-09-18 16:21:06.333         74.76  2019-07-15         CheckM8
#
# [361519 rows x 12 columns]

# %%
categorical_feats = ['IsCreditInvoice', 'StatementTransactionType', 'PaymentType']
continuous_feats = ['OriginalInvoiceAmount', 'AmountOutstanding', 'PaymentValue']

# %%
df[categorical_feats]
# Out:
#         IsCreditInvoice StatementTransactionType     PaymentType
# 0                     1                      JRN  Barclays Multi
# 1                     1                      JRN  Barclays Multi
# 2                     1                      JRN  Barclays Multi
# 3                     0                      INV  Barclays Multi
# 4                     1                      JRN  Barclays Multi
# ...                 ...                      ...             ...
# 361514                0                      INV  Barclays Multi
# 361515                0                      INV  Barclays Multi
# 361516                0                      INV         CheckM8
# 361517                0                      INV  Barclays Multi
# 361518                0                      INV         CheckM8
#
# [361519 rows x 3 columns]

# %%
# encoding categorical variables as integers, not needed
'''
df["StatementTransactionType"] = df["StatementTransactionType"].astype('category').cat.codes
df["PaymentType"] = df["PaymentType"].astype('category').cat.codes
df["IsCreditInvoice"] = df["IsCreditInvoice"].astype('category').cat.codes
'''
# Out:
# '\ndf["StatementTransactionType"] = df["StatementTransactionType"].astype(\'category\').cat.codes\ndf["PaymentType"] = df["PaymentType"].astype(\'category\').cat.codes\ndf["IsCreditInvoice"] = df["IsCreditInvoice"].astype(\'category\').cat.codes\n'

# %%
df[categorical_feats + continuous_feats].describe()
# Out:
#        IsCreditInvoice  OriginalInvoiceAmount  AmountOutstanding  PaymentValue
# count    361519.000000           3.615190e+05      361519.000000  3.615190e+05
# mean          0.023741           3.306604e+03           0.064838  3.176434e+03
# std           0.152243           5.410108e+04          15.607989  5.358945e+04
# min           0.000000          -1.165304e+06        -308.280000 -1.165304e+06
# 25%           0.000000           8.142000e+01           0.000000  8.076000e+01
# 50%           0.000000           2.160000e+02           0.000000  2.141800e+02
# 75%           0.000000           7.158000e+02           0.000000  7.083700e+02
# max           1.000000           7.738426e+06        7714.150000  7.738426e+06

# %%
km =  KPrototypes(n_clusters=3, init='Huang', verbose=1, n_init=2)

results = []

for _ in range(5):
    km =  KPrototypes(n_clusters=3, init='Huang', verbose=1, n_init=2)
    clusters = km.fit_predict(df[categorical_feats + continuous_feats].sample(frac=0.2, random_state=1), categorical=[0,1,2])
    
    results.append([km, clusters])
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 53, ncost: 392121146114826.56
# Run: 1, iteration: 2/100, moves: 24, ncost: 391575849154200.6
# Run: 1, iteration: 3/100, moves: 22, ncost: 391530463407313.06
# Run: 1, iteration: 4/100, moves: 8, ncost: 391514759730932.3
# Run: 1, iteration: 5/100, moves: 2, ncost: 391513184541050.6
# Run: 1, iteration: 6/100, moves: 0, ncost: 391513184541050.6
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 716, ncost: 246464296326100.34
# Run: 2, iteration: 2/100, moves: 164, ncost: 192242770115936.44
# Run: 2, iteration: 3/100, moves: 44, ncost: 170651321022738.7
# Run: 2, iteration: 4/100, moves: 22, ncost: 149674553262530.1
# Run: 2, iteration: 5/100, moves: 10, ncost: 137392656926656.39
# Run: 2, iteration: 6/100, moves: 3, ncost: 135424866796063.38
# Run: 2, iteration: 7/100, moves: 0, ncost: 135424866796063.38
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 629, ncost: 241704409098096.34
# Run: 1, iteration: 2/100, moves: 150, ncost: 190171647506580.56
# Run: 1, iteration: 3/100, moves: 40, ncost: 170651321022738.78
# Run: 1, iteration: 4/100, moves: 22, ncost: 149674553262530.12
# Run: 1, iteration: 5/100, moves: 10, ncost: 137392656926656.45
# Run: 1, iteration: 6/100, moves: 3, ncost: 135424866796063.38
# Run: 1, iteration: 7/100, moves: 0, ncost: 135424866796063.38
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 1148, ncost: 220218703912907.88
# Run: 2, iteration: 2/100, moves: 692, ncost: 161970533351975.2
# Run: 2, iteration: 3/100, moves: 408, ncost: 103533423385494.53
# Run: 2, iteration: 4/100, moves: 191, ncost: 78215787402433.3
# Run: 2, iteration: 5/100, moves: 49, ncost: 76468803271933.73
# Run: 2, iteration: 6/100, moves: 11, ncost: 76316370933385.78
# Run: 2, iteration: 7/100, moves: 6, ncost: 76270408070262.83
# Run: 2, iteration: 8/100, moves: 6, ncost: 76225279591720.39
# Run: 2, iteration: 9/100, moves: 4, ncost: 76200148560369.62
# Run: 2, iteration: 10/100, moves: 7, ncost: 75238129178920.1
# Run: 2, iteration: 11/100, moves: 17, ncost: 71369800804260.8
# Run: 2, iteration: 12/100, moves: 5, ncost: 70877844804380.58
# Run: 2, iteration: 13/100, moves: 3, ncost: 70852366814017.66
# Run: 2, iteration: 14/100, moves: 0, ncost: 70852366814017.66
# Best run was number 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 3191, ncost: 218219856660435.9
# Run: 1, iteration: 2/100, moves: 1803, ncost: 167321678847661.72
# Run: 1, iteration: 3/100, moves: 697, ncost: 120767442868534.48
# Run: 1, iteration: 4/100, moves: 273, ncost: 81126531887885.39
# Run: 1, iteration: 5/100, moves: 87, ncost: 76670225912639.36
# Run: 1, iteration: 6/100, moves: 18, ncost: 76330873143966.56
# Run: 1, iteration: 7/100, moves: 8, ncost: 76270408070262.89
# Run: 1, iteration: 8/100, moves: 6, ncost: 76225279591720.4
# Run: 1, iteration: 9/100, moves: 4, ncost: 76200148560369.64
# Run: 1, iteration: 10/100, moves: 7, ncost: 75238129178920.23
# Run: 1, iteration: 11/100, moves: 17, ncost: 71369800804260.92
# Run: 1, iteration: 12/100, moves: 5, ncost: 70877844804380.56
# Run: 1, iteration: 13/100, moves: 3, ncost: 70852366814017.61
# Run: 1, iteration: 14/100, moves: 0, ncost: 70852366814017.61
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 855, ncost: 216816385397847.34
# Run: 2, iteration: 2/100, moves: 951, ncost: 160660677418332.78
# Run: 2, iteration: 3/100, moves: 486, ncost: 102169981775399.58
# Run: 2, iteration: 4/100, moves: 207, ncost: 78355888739579.55
# Run: 2, iteration: 5/100, moves: 50, ncost: 76508717003031.9
# Run: 2, iteration: 6/100, moves: 13, ncost: 76316370933385.78
# Run: 2, iteration: 7/100, moves: 6, ncost: 76270408070262.84
# Run: 2, iteration: 8/100, moves: 6, ncost: 76225279591720.44
# Run: 2, iteration: 9/100, moves: 4, ncost: 76200148560369.62
# Run: 2, iteration: 10/100, moves: 7, ncost: 75238129178920.14
# Run: 2, iteration: 11/100, moves: 17, ncost: 71369800804260.86
# Run: 2, iteration: 12/100, moves: 5, ncost: 70877844804380.52
# Run: 2, iteration: 13/100, moves: 3, ncost: 70852366814017.62
# Run: 2, iteration: 14/100, moves: 0, ncost: 70852366814017.62
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 1133, ncost: 228715998376434.53
# Run: 1, iteration: 2/100, moves: 684, ncost: 167813195639251.84
# Run: 1, iteration: 3/100, moves: 432, ncost: 113758571905716.12
# Run: 1, iteration: 4/100, moves: 216, ncost: 78834306106105.78
# Run: 1, iteration: 5/100, moves: 56, ncost: 76571860932506.33
# Run: 1, iteration: 6/100, moves: 15, ncost: 76322903798564.44
# Run: 1, iteration: 7/100, moves: 7, ncost: 76270408070262.84
# Run: 1, iteration: 8/100, moves: 6, ncost: 76225279591720.39
# Run: 1, iteration: 9/100, moves: 4, ncost: 76200148560369.64
# Run: 1, iteration: 10/100, moves: 7, ncost: 75238129178920.17
# Run: 1, iteration: 11/100, moves: 17, ncost: 71369800804260.84
# Run: 1, iteration: 12/100, moves: 5, ncost: 70877844804380.55
# Run: 1, iteration: 13/100, moves: 3, ncost: 70852366814017.62
# Run: 1, iteration: 14/100, moves: 0, ncost: 70852366814017.62
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 0, ncost: 391499538315225.8
# Best run was number 1
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/100, moves: 97, ncost: 187199250098684.38
# Run: 1, iteration: 2/100, moves: 36, ncost: 169199605605463.3
# Run: 1, iteration: 3/100, moves: 20, ncost: 149674553262530.4
# Run: 1, iteration: 4/100, moves: 10, ncost: 137392656926656.67
# Run: 1, iteration: 5/100, moves: 3, ncost: 135424866796063.38
# Run: 1, iteration: 6/100, moves: 0, ncost: 135424866796063.38
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/100, moves: 1141, ncost: 265666151404302.5
# Run: 2, iteration: 2/100, moves: 230, ncost: 202181194887170.5
# Run: 2, iteration: 3/100, moves: 59, ncost: 176884069349505.38
# Run: 2, iteration: 4/100, moves: 29, ncost: 151820619447801.47
# Run: 2, iteration: 5/100, moves: 10, ncost: 139857569750405.67
# Run: 2, iteration: 6/100, moves: 5, ncost: 135424866796063.38
# Run: 2, iteration: 7/100, moves: 0, ncost: 135424866796063.38
# Best run was number 1

# %%
for result in results:
    print(result[0].cluster_centroids_[0])
# Out:
# [[ 2.63799772e+03  1.65602745e-01  2.51642091e+03]
#  [ 2.78753608e+06  0.00000000e+00  2.70994735e+06]
#  [-8.51641860e+05  0.00000000e+00 -8.39953880e+05]]
# [[1.94427534e+03 1.65777039e-01 1.85395771e+03]
#  [3.34391234e+06 0.00000000e+00 3.26613394e+06]
#  [7.23465262e+05 0.00000000e+00 6.90715583e+05]]
# [[3.34391234e+06 0.00000000e+00 3.26613394e+06]
#  [7.23465262e+05 1.02729070e-15 6.90715583e+05]
#  [1.94427534e+03 1.65777039e-01 1.85395771e+03]]
# [[1.94427534e+03 1.65777039e-01 1.85395771e+03]
#  [7.23465262e+05 0.00000000e+00 6.90715583e+05]
#  [3.34391234e+06 0.00000000e+00 3.26613394e+06]]
# [[-8.51641860e+05  0.00000000e+00 -8.39953880e+05]
#  [ 2.78753608e+06  0.00000000e+00  2.70994735e+06]
#  [ 2.63799772e+03  1.65602745e-01  2.51642091e+03]]

# %%
cluster_centers = [result[0].cluster_centroids_[0] for result in results]

# %%
cluster_centers
# Out:
# [array([[   2637.99772044,       0.16560274,    2516.42091359],
#         [2787536.07941179,       0.        , 2709947.34823531],
#         [-851641.86      ,       0.        , -839953.88      ]]),
#  array([[   1944.2753386 ,       0.16577704,    1853.9577132 ],
#         [3343912.34363638,       0.        , 3266133.93727273],
#         [ 723465.26180723,       0.        ,  690715.5833735 ]]),
#  array([[3343912.34363637,       0.        , 3266133.93727274],
#         [ 723465.26180723,       0.        ,  690715.58337349],
#         [   1944.2753386 ,       0.16577704,    1853.9577132 ]]),
#  array([[   1944.2753386 ,       0.16577704,    1853.9577132 ],
#         [ 723465.26180723,       0.        ,  690715.5833735 ],
#         [3343912.34363637,       0.        , 3266133.93727273]]),
#  array([[-851641.86      ,       0.        , -839953.88      ],
#         [2787536.07941177,       0.        , 2709947.3482353 ],
#         [   2637.99772044,       0.16560274,    2516.42091359]])]

# %%
cluster_centers[0].shape
# Out:
# (3, 3)

# %%
cont_clusters = np.mean(cluster_centers, axis=0)

# %%
np.set_printoptions(suppress=True)

# %%
for i in range(len(continuous_feats)):
    print(f"Cluster {i}: {np.round(cont_clusters[i], 2)}")
# Out:
# Cluster 0: [499759.41      0.1  486480.88]
# Cluster 1: [2073183.01       0.   2013491.96]
# Cluster 2: [644063.6       0.07 624253.2 ]

# %%
continuous_feats
categorical_feats
# Out:
# ['IsCreditInvoice', 'StatementTransactionType', 'PaymentType']

# %%
'''
results: 
['IsCreditInvoice', 'StatementTransactionType', 'PaymentType']
cluster 1: ['0' 'INV' 'Barclays Multi']
cluster 2: ['1' 'CSH' 'Barclays Multi']

'OriginalInvoiceAmount', 'AmountOutstanding', 'PaymentValue'
Cluster 0: [499759.41      0.1  486480.88]
Cluster 1: [2073183.01       0.   2013491.96]
Cluster 2: [644063.6       0.07 624253.2 ]

'''
