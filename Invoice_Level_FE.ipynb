# %%
import os
import sys
import pandas as pd
from pathlib import Path
import numpy as np
from kmodes.kmodes import KModes
from kmodes.kprototypes import KPrototypes
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./Engineered_Data/data.csv')

# %%
df
# Out:
#         AveragePaymentValue  CustomerKey     DueDate  EarliestPaymentDate  \
# 0                   168.000     16745090  2018-03-02           2018-11-23
# 1                   819.600     16743947  2018-02-03           2018-10-26
# 2                   718.200     16836264  2018-02-08           2018-11-05
# 3                  1873.080     16843107  2018-03-02           2018-09-04
# 4                  1316.090     16739410  2018-02-11           2018-09-26
# ...                     ...          ...         ...                  ...
# 272237               24.815     16849111  2019-07-30  2019-07-30 00:00:00
# 272238              178.165     16847651  2019-07-30  2019-09-24 00:00:00
# 272239               36.310     16917308  2019-07-30  2019-07-29 00:00:00
# 272240              311.440     16782671  2019-07-30  2019-07-22 00:00:00
# 272241              226.750     16876991  2019-07-30  2019-08-16 00:00:00
#
#         InvoiceKey  NumPayments  OriginalInvoiceAmount    LatestPaymentDate  \
# 0        195519971          1.0                 168.00           2018-11-23
# 1        196442471          1.0                 819.60           2018-10-26
# 2        196563186          1.0                 749.40           2018-11-05
# 3        196711370          1.0                1873.08           2018-09-04
# 4        197134638          1.0                1316.09           2018-09-26
# ...            ...          ...                    ...                  ...
# 272237   196911580          2.0                  49.63  2019-08-30 00:00:00
# 272238   195362531          2.0                 356.33  2019-10-07 00:00:00
# 272239   196871858          2.0                  72.62  2019-08-09 00:00:00
# 272240   195891626          2.0                 311.44  2019-09-18 00:00:00
# 272241   196139086          2.0                 453.50  2019-09-20 00:00:00
#
#            PaymentType  TotalPaymentValue  RaisedDate StatementTransactionType
# 0       Barclays Multi             168.00  2018-01-03                      INV
# 1       Barclays Multi             819.60  2018-01-04                      INV
# 2       Barclays Multi             718.20  2018-01-09                      INV
# 3       Barclays Multi            1873.08  2018-01-11                      INV
# 4       Barclays Multi            1316.09  2018-01-12                      INV
# ...                ...                ...         ...                      ...
# 272237  Barclays Multi              49.63  2019-06-30                      INV
# 272238  Barclays Multi             356.33  2019-06-30                      INV
# 272239  Barclays Multi              72.62  2019-06-30                      INV
# 272240         CheckM8             622.88  2019-06-30                      INV
# 272241  Barclays Multi             453.50  2019-06-30                      INV
#
# [272242 rows x 12 columns]

# %%
# Is this invoice paid fully ? (0/1 binary)
# just compare the original invoice amount with the total payment

df['IsInvoicePaidFully'] = df.apply(lambda row: 1 if row['TotalPaymentValue'] >= row['OriginalInvoiceAmount'] else 0, axis=1)

# %%
df
# Out:
#         AveragePaymentValue  CustomerKey     DueDate  EarliestPaymentDate  \
# 0                   168.000     16745090  2018-03-02           2018-11-23
# 1                   819.600     16743947  2018-02-03           2018-10-26
# 2                   718.200     16836264  2018-02-08           2018-11-05
# 3                  1873.080     16843107  2018-03-02           2018-09-04
# 4                  1316.090     16739410  2018-02-11           2018-09-26
# ...                     ...          ...         ...                  ...
# 272237               24.815     16849111  2019-07-30  2019-07-30 00:00:00
# 272238              178.165     16847651  2019-07-30  2019-09-24 00:00:00
# 272239               36.310     16917308  2019-07-30  2019-07-29 00:00:00
# 272240              311.440     16782671  2019-07-30  2019-07-22 00:00:00
# 272241              226.750     16876991  2019-07-30  2019-08-16 00:00:00
#
#         InvoiceKey  NumPayments  OriginalInvoiceAmount    LatestPaymentDate  \
# 0        195519971          1.0                 168.00           2018-11-23
# 1        196442471          1.0                 819.60           2018-10-26
# 2        196563186          1.0                 749.40           2018-11-05
# 3        196711370          1.0                1873.08           2018-09-04
# 4        197134638          1.0                1316.09           2018-09-26
# ...            ...          ...                    ...                  ...
# 272237   196911580          2.0                  49.63  2019-08-30 00:00:00
# 272238   195362531          2.0                 356.33  2019-10-07 00:00:00
# 272239   196871858          2.0                  72.62  2019-08-09 00:00:00
# 272240   195891626          2.0                 311.44  2019-09-18 00:00:00
# 272241   196139086          2.0                 453.50  2019-09-20 00:00:00
#
#            PaymentType  TotalPaymentValue  RaisedDate  \
# 0       Barclays Multi             168.00  2018-01-03
# 1       Barclays Multi             819.60  2018-01-04
# 2       Barclays Multi             718.20  2018-01-09
# 3       Barclays Multi            1873.08  2018-01-11
# 4       Barclays Multi            1316.09  2018-01-12
# ...                ...                ...         ...
# 272237  Barclays Multi              49.63  2019-06-30
# 272238  Barclays Multi             356.33  2019-06-30
# 272239  Barclays Multi              72.62  2019-06-30
# 272240         CheckM8             622.88  2019-06-30
# 272241  Barclays Multi             453.50  2019-06-30
#
#        StatementTransactionType  IsInvoicePaidFully
# 0                           INV                   1
# 1                           INV                   1
# 2                           INV                   0
# 3                           INV                   1
# 4                           INV                   1
# ...                         ...                 ...
# 272237                      INV                   1
# 272238                      INV                   1
# 272239                      INV                   1
# 272240                      INV                   1
# 272241                      INV                   1
#
# [272242 rows x 13 columns]

# %%
# Raised time to first payment
# difference between earliestpaymentdate and raised date

# convert to pd.datetime
df['RaisedDate'] =  pd.to_datetime(df['RaisedDate'])
df['DueDate'] =  pd.to_datetime(df['DueDate'])
df['EarliestPaymentDate'] =  pd.to_datetime(df['EarliestPaymentDate'])
df['LatestPaymentDate'] =  pd.to_datetime(df['LatestPaymentDate'])

df['RaisedToFirstPayment'] = (df['EarliestPaymentDate'] - df['RaisedDate']).dt.days

# %%
# Raised time to cleared(OriginalInvoiceAmount = Sum(PaymentValues)) in days
# if not cleared, -1, otherwise number of days until latest payment

df['RaisedToCleared'] = df.apply(lambda row: np.nan if row['IsInvoicePaidFully'] == 0 else (row['LatestPaymentDate'] - row['RaisedDate']).days, axis=1)

# %%
'''
Invoice cleared on time before or on DueDate (0/1) binary

paid fully and latest payment date <= duedate

'''

df['IsClearedOnTime'] = df.apply(lambda row: 1 if row['IsInvoicePaidFully'] == 1 and row['LatestPaymentDate'] <= row['DueDate'] else 0, axis=1)

# %%
df
# Out:
#         AveragePaymentValue  CustomerKey    DueDate EarliestPaymentDate  \
# 0                   168.000     16745090 2018-03-02          2018-11-23
# 1                   819.600     16743947 2018-02-03          2018-10-26
# 2                   718.200     16836264 2018-02-08          2018-11-05
# 3                  1873.080     16843107 2018-03-02          2018-09-04
# 4                  1316.090     16739410 2018-02-11          2018-09-26
# ...                     ...          ...        ...                 ...
# 272237               24.815     16849111 2019-07-30          2019-07-30
# 272238              178.165     16847651 2019-07-30          2019-09-24
# 272239               36.310     16917308 2019-07-30          2019-07-29
# 272240              311.440     16782671 2019-07-30          2019-07-22
# 272241              226.750     16876991 2019-07-30          2019-08-16
#
#         InvoiceKey  NumPayments  OriginalInvoiceAmount LatestPaymentDate  \
# 0        195519971          1.0                 168.00        2018-11-23
# 1        196442471          1.0                 819.60        2018-10-26
# 2        196563186          1.0                 749.40        2018-11-05
# 3        196711370          1.0                1873.08        2018-09-04
# 4        197134638          1.0                1316.09        2018-09-26
# ...            ...          ...                    ...               ...
# 272237   196911580          2.0                  49.63        2019-08-30
# 272238   195362531          2.0                 356.33        2019-10-07
# 272239   196871858          2.0                  72.62        2019-08-09
# 272240   195891626          2.0                 311.44        2019-09-18
# 272241   196139086          2.0                 453.50        2019-09-20
#
#            PaymentType  TotalPaymentValue RaisedDate StatementTransactionType  \
# 0       Barclays Multi             168.00 2018-01-03                      INV
# 1       Barclays Multi             819.60 2018-01-04                      INV
# 2       Barclays Multi             718.20 2018-01-09                      INV
# 3       Barclays Multi            1873.08 2018-01-11                      INV
# 4       Barclays Multi            1316.09 2018-01-12                      INV
# ...                ...                ...        ...                      ...
# 272237  Barclays Multi              49.63 2019-06-30                      INV
# 272238  Barclays Multi             356.33 2019-06-30                      INV
# 272239  Barclays Multi              72.62 2019-06-30                      INV
# 272240         CheckM8             622.88 2019-06-30                      INV
# 272241  Barclays Multi             453.50 2019-06-30                      INV
#
#         IsInvoicePaidFully  RaisedToFirstPayment  RaisedToCleared  \
# 0                        1                   324            324.0
# 1                        1                   295            295.0
# 2                        0                   300              NaN
# 3                        1                   236            236.0
# 4                        1                   257            257.0
# ...                    ...                   ...              ...
# 272237                   1                    30             61.0
# 272238                   1                    86             99.0
# 272239                   1                    29             40.0
# 272240                   1                    22             80.0
# 272241                   1                    47             82.0
#
#         IsClearedOnTime
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 272237                0
# 272238                0
# 272239                0
# 272240                0
# 272241                0
#
# [272242 rows x 16 columns]

# %%
df.to_csv(path_or_buf='./Engineered_Data/invoice_data.csv', index=False)
