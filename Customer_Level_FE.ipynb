# %%
import os
import sys
import pandas as pd
from pathlib import Path
import numpy as np
from kmodes.kmodes import KModes
from kmodes.kprototypes import KPrototypes
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
'''
Fraction of invoice fully paid (# cleared invoices / # invoices per customer) = sum(IsInvoicePaidFully) / count(numInvoices)
fraction of invoice fully paid on time  (# cleared invoices before or on duedate / # invoices per customer) = sum(IsClearedOnTime) / count(numInvoices)
Average time until first payment = mean(RaisedToFirstPayment)
Average payment amount = mean(AveragePaymentValue)
- Average number of payments = mean(NumPayments)
- Number of invoices (grouby count)
'''

df = pd.read_csv('./Engineered_Data/invoice_data.csv')

# %%
df
# Out:
#         AveragePaymentValue  CustomerKey     DueDate EarliestPaymentDate  \
# 0                   168.000     16745090  2018-03-02          2018-11-23
# 1                   819.600     16743947  2018-02-03          2018-10-26
# 2                   718.200     16836264  2018-02-08          2018-11-05
# 3                  1873.080     16843107  2018-03-02          2018-09-04
# 4                  1316.090     16739410  2018-02-11          2018-09-26
# ...                     ...          ...         ...                 ...
# 272237               24.815     16849111  2019-07-30          2019-07-30
# 272238              178.165     16847651  2019-07-30          2019-09-24
# 272239               36.310     16917308  2019-07-30          2019-07-29
# 272240              311.440     16782671  2019-07-30          2019-07-22
# 272241              226.750     16876991  2019-07-30          2019-08-16
#
#         InvoiceKey  NumPayments  OriginalInvoiceAmount LatestPaymentDate  \
# 0        195519971          1.0                 168.00        2018-11-23
# 1        196442471          1.0                 819.60        2018-10-26
# 2        196563186          1.0                 749.40        2018-11-05
# 3        196711370          1.0                1873.08        2018-09-04
# 4        197134638          1.0                1316.09        2018-09-26
# ...            ...          ...                    ...               ...
# 272237   196911580          2.0                  49.63        2019-08-30
# 272238   195362531          2.0                 356.33        2019-10-07
# 272239   196871858          2.0                  72.62        2019-08-09
# 272240   195891626          2.0                 311.44        2019-09-18
# 272241   196139086          2.0                 453.50        2019-09-20
#
#            PaymentType  TotalPaymentValue  RaisedDate  \
# 0       Barclays Multi             168.00  2018-01-03
# 1       Barclays Multi             819.60  2018-01-04
# 2       Barclays Multi             718.20  2018-01-09
# 3       Barclays Multi            1873.08  2018-01-11
# 4       Barclays Multi            1316.09  2018-01-12
# ...                ...                ...         ...
# 272237  Barclays Multi              49.63  2019-06-30
# 272238  Barclays Multi             356.33  2019-06-30
# 272239  Barclays Multi              72.62  2019-06-30
# 272240         CheckM8             622.88  2019-06-30
# 272241  Barclays Multi             453.50  2019-06-30
#
#        StatementTransactionType  IsInvoicePaidFully  RaisedToFirstPayment  \
# 0                           INV                   1                   324
# 1                           INV                   1                   295
# 2                           INV                   0                   300
# 3                           INV                   1                   236
# 4                           INV                   1                   257
# ...                         ...                 ...                   ...
# 272237                      INV                   1                    30
# 272238                      INV                   1                    86
# 272239                      INV                   1                    29
# 272240                      INV                   1                    22
# 272241                      INV                   1                    47
#
#         RaisedToCleared  IsClearedOnTime
# 0                 324.0                0
# 1                 295.0                0
# 2                   NaN                0
# 3                 236.0                0
# 4                 257.0                0
# ...                 ...              ...
# 272237             61.0                0
# 272238             99.0                0
# 272239             40.0                0
# 272240             80.0                0
# 272241             82.0                0
#
# [272242 rows x 16 columns]

# %%
df['NumInvoices'] = 1

# %%
df = df.groupby('CustomerKey').agg({'IsClearedOnTime': 'sum',
                               'IsInvoicePaidFully': 'sum',
                             'AveragePaymentValue': 'mean',
                              'NumPayments': 'mean',
                              'AveragePaymentValue': 'mean',
                              'NumInvoices': 'count'
                              }).reset_index()

# %%
df
# Out:
#        CustomerKey  IsClearedOnTime  IsInvoicePaidFully  AveragePaymentValue  \
# 0         16721154                4                  11            59.680000
# 1         16721167                0                  12           190.075000
# 2         16721203                0                  12            64.442500
# 3         16721207                0                  24           515.975417
# 4         16721212                9                  11           411.229091
# ...            ...              ...                 ...                  ...
# 12846     16980240               16                  22           426.218182
# 12847     16980268               16                  16           437.421250
# 12848     16980375                0                  62           167.441129
# 12849     16980435                0                  12           342.846667
# 12850     16984799                0                  10           746.123000
#
#        NumPayments  NumInvoices
# 0              1.0           11
# 1              1.0           12
# 2              1.0           12
# 3              1.0           24
# 4              1.0           11
# ...            ...          ...
# 12846          1.0           22
# 12847          1.0           16
# 12848          1.0           62
# 12849          1.0           12
# 12850          1.0           10
#
# [12851 rows x 6 columns]

# %%
df['FractionFullyPaid'] = df['IsInvoicePaidFully'] / df['NumInvoices']
df['FractionClearedOnTime'] = df['IsClearedOnTime'] /  df['NumInvoices']

# %%
df
# Out:
#        CustomerKey  IsClearedOnTime  IsInvoicePaidFully  AveragePaymentValue  \
# 0         16721154                4                  11            59.680000
# 1         16721167                0                  12           190.075000
# 2         16721203                0                  12            64.442500
# 3         16721207                0                  24           515.975417
# 4         16721212                9                  11           411.229091
# ...            ...              ...                 ...                  ...
# 12846     16980240               16                  22           426.218182
# 12847     16980268               16                  16           437.421250
# 12848     16980375                0                  62           167.441129
# 12849     16980435                0                  12           342.846667
# 12850     16984799                0                  10           746.123000
#
#        NumPayments  NumInvoices  FractionFullyPaid  FractionClearedOnTime
# 0              1.0           11                1.0               0.363636
# 1              1.0           12                1.0               0.000000
# 2              1.0           12                1.0               0.000000
# 3              1.0           24                1.0               0.000000
# 4              1.0           11                1.0               0.818182
# ...            ...          ...                ...                    ...
# 12846          1.0           22                1.0               0.727273
# 12847          1.0           16                1.0               1.000000
# 12848          1.0           62                1.0               0.000000
# 12849          1.0           12                1.0               0.000000
# 12850          1.0           10                1.0               0.000000
#
# [12851 rows x 8 columns]

# %%
df.rename(columns={"IsClearedOnTime": "NumClearedOnTime", 
                   "IsInvoicePaidFully": "NumPaidFully",
                  "AveragePaymentValue": "AveragePaymentAmount",
                  "NumPayments": "AverageNumPayments"}, inplace=True)

# %%
df
# Out:
#        CustomerKey  NumClearedOnTime  NumPaidFully  AveragePaymentAmount  \
# 0         16721154                 4            11             59.680000
# 1         16721167                 0            12            190.075000
# 2         16721203                 0            12             64.442500
# 3         16721207                 0            24            515.975417
# 4         16721212                 9            11            411.229091
# ...            ...               ...           ...                   ...
# 12846     16980240                16            22            426.218182
# 12847     16980268                16            16            437.421250
# 12848     16980375                 0            62            167.441129
# 12849     16980435                 0            12            342.846667
# 12850     16984799                 0            10            746.123000
#
#        AverageNumPayments  NumInvoices  FractionFullyPaid  \
# 0                     1.0           11                1.0
# 1                     1.0           12                1.0
# 2                     1.0           12                1.0
# 3                     1.0           24                1.0
# 4                     1.0           11                1.0
# ...                   ...          ...                ...
# 12846                 1.0           22                1.0
# 12847                 1.0           16                1.0
# 12848                 1.0           62                1.0
# 12849                 1.0           12                1.0
# 12850                 1.0           10                1.0
#
#        FractionClearedOnTime
# 0                   0.363636
# 1                   0.000000
# 2                   0.000000
# 3                   0.000000
# 4                   0.818182
# ...                      ...
# 12846               0.727273
# 12847               1.000000
# 12848               0.000000
# 12849               0.000000
# 12850               0.000000
#
# [12851 rows x 8 columns]

# %%
df.describe()
# Out:
#         CustomerKey  NumClearedOnTime  NumPaidFully  AveragePaymentAmount  \
# count  1.285100e+04      12851.000000  12851.000000          12851.000000
# mean   1.682213e+07          7.127150     21.116645            318.011819
# std    8.098659e+04         20.233905     72.337124            314.160163
# min    1.672115e+07          0.000000      0.000000              0.010000
# 25%    1.674237e+07          1.000000     11.000000             99.437576
# 50%    1.681980e+07          5.000000     12.000000            192.359091
# 75%    1.688581e+07          9.000000     13.000000            434.215606
# max    1.698480e+07       1116.000000   3635.000000           1804.255833
#
#        AverageNumPayments   NumInvoices  FractionFullyPaid  \
# count        12851.000000  12851.000000       12851.000000
# mean             1.002920     21.184499           0.997031
# std              0.050506     72.693455           0.021205
# min              1.000000     10.000000           0.000000
# 25%              1.000000     11.000000           1.000000
# 50%              1.000000     12.000000           1.000000
# 75%              1.000000     13.000000           1.000000
# max              4.500000   3636.000000           1.000000
#
#        FractionClearedOnTime
# count           12851.000000
# mean                0.403839
# std                 0.335002
# min                 0.000000
# 25%                 0.083333
# 50%                 0.363636
# 75%                 0.692308
# max                 1.000000

# %%
df.to_csv(path_or_buf='./Engineered_Data/customer_data.csv', index=False)
